# %% [markdown]
# # Spatial Join using Geopandas - MLB Ballparks example

# %% [markdown]
# In this example, we're going to demonstrate how to conduct a spatial join ("sjoin") using two shapefiles. We will be working with two datasets. The first dataset is a shapefile of Major League Baseball ("MLB") ballparks with their geospatial coordinates (longitude, latitude). The MLB ballparks can be found at this link: https://www.sciencebase.gov/catalog/item/4f4e4a48e4b07f02db6230c7.
#
# The other is a shapefile of cities from the U.S. Census Bureau. The shapefile is available through Census Bureau's TIGER/Line shapefile archive. The shapefile used in this example can be found here: https://www.census.gov/cgi-bin/geo/shapefiles/index.php?year=2018&layergroup=Urban+Areas.
#
# The goal is to match the MLB ballparks with the cities and states that they're located in. The sjoin function helps us achieve this goal.

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
from shapely.geometry import Point, Polygon
#from shapely.geometry.polygon import Polygon
from pandas import Series, DataFrame
import geopandas as gpd

# %% [markdown]
# ## First, we read in the Census Bureau shapefile

# %%
df_cities = gpd.read_file("cb_2018_us_ua10_500k.shp")

# %% [markdown]
# We use the geopandas function "read_file" to read in the shapefiles. This function transforms the data in the shapefile as a GeoDataframe, which is similiar to a Pandas DataFrame but with a geometry column that has the shape (point, line, polygon, multipolygon, etc.) with the corresponding spatial coordinates (longitude, latitude). We'll call our Census Bureau GeoDataFrame "df_cities".

# %%
df_cities.head()
# Out:
#   UACE10      AFFGEOID10 GEOID10              NAME10 LSAD10 UATYP10  \
# 0  88732  400C100US88732   88732          Tucson, AZ     75       U
# 1  01819  400C100US01819   01819         Alturas, CA     76       C
# 2  22366  400C100US22366   22366   Davenport, IA--IL     75       U
# 3  93322  400C100US93322   93322  Waynesboro, PA--MD     76       C
# 4  02548  400C100US02548   02548          Angola, IN     76       C
#
#      ALAND10  AWATER10                                           geometry
# 0  915276150   2078695  MULTIPOLYGON (((-110.81345 32.11910, -110.7987...
# 1    4933312     16517  MULTIPOLYGON (((-120.54610 41.51264, -120.5459...
# 2  357345121  21444164  MULTIPOLYGON (((-90.36678 41.53636, -90.36462 ...
# 3   45455957     88872  MULTIPOLYGON (((-77.50746 39.71577, -77.50605 ...
# 4   23646957   3913803  MULTIPOLYGON (((-85.01157 41.59300, -85.00589 ...

# %% [markdown]
# In df_cities, we have the geometry of our cities (or urban areas) which are multipolygons that have several geospatial coordinates that represent the boundaries of the cities.

# %% [markdown]
# ## Next, we read in the MLB Ballparks shapefile

# %%
df_ballparks = gpd.read_file("Stadiums_MLB.shp")

# %% [markdown]
# We'll name this GeoDataFrame "df_ballparks". Let's see what's included in df_ballparks.

# %%
df_ballparks.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 31 columns):
# SECTOR        30 non-null object
# SUBSECTOR     30 non-null object
# PRIMARY_TY    30 non-null object
# SEC_CLASS     30 non-null object
# DATE_CREAT    30 non-null object
# COMP_AFFIL    0 non-null object
# NAME1         30 non-null object
# NAME2         0 non-null object
# NAME3         0 non-null object
# ADDRESS1      30 non-null object
# ADDRESS2      0 non-null object
# PO_BOX        0 non-null object
# PO_ZIP        0 non-null object
# CITY          30 non-null object
# STATE         30 non-null object
# ZIP           30 non-null float64
# ZIP_4         10 non-null object
# COUNTY        30 non-null object
# HSIP_AOI      30 non-null object
# FEMA_REGIO    30 non-null float64
# LATITUDE      30 non-null float64
# LONGITUDE     30 non-null float64
# RELIABILIT    30 non-null object
# COORSOURCE    30 non-null object
# COMMENTS_1    14 non-null object
# LEAGUE        30 non-null object
# DIVISION      30 non-null object
# CAPACITY      30 non-null float64
# ROOF_TYPE     30 non-null object
# TEAM          30 non-null object
# geometry      30 non-null geometry
# dtypes: float64(5), geometry(1), object(25)
# memory usage: 7.4+ KB

# %% [markdown]
# We'll subset the df_ballparks by just keeping only the following columns:
#  - NAME1
#  - CITY
#  - STATE
#  - TEAM
#  - geometry

# %%
df_ballparks = df_ballparks[['NAME1','CITY','STATE','TEAM','geometry']]
df_ballparks.head()
# Out:
#                       NAME1          CITY STATE  \
# 0  Angel Stadium of Anaheim       Anaheim    CA
# 1               Chase Field       Phoenix    AZ
# 2        Citizens Bank Park  Philadelphia    PA
# 3             Comerica Park       Detroit    MI
# 4               Coors Field        Denver    CO
#
#                             TEAM                     geometry
# 0  Los Angeles Angels of Anaheim  POINT (-117.88204 33.80129)
# 1           Arizona Diamondbacks  POINT (-112.06673 33.44501)
# 2          Philadelphia Phillies   POINT (-75.16665 39.90618)
# 3                 Detroit Tigers   POINT (-83.04886 42.33912)
# 4               Colorado Rockies  POINT (-104.99442 39.75664)

# %% [markdown]
# The geometry of the MLB ballparks are points, which is a simple geometry that has only one longitude and latitude coordinate.

# %% [markdown]
# ## Now, we can do the spatial join (or sjoin)

# %% [markdown]
# We're going to do a right (how=right) sjoin (can also do a left join) using df_ballparks as the left GeoDataFrame and df_cities as the right GeoDataFrame. The operator keyword we're using is "within" (op="within") because we want to place the points of the MLB ballparks within the polygons of the cities. This will give us the city and state these MLB ballparks are located. We'll call our joined GeoDataFrame "join_df".

# %%
#https://stackoverflow.com/questions/58513123/link-each-point-in-one-geopandas-dataframe-to-polygons-in-another-dataframe
join_df=gpd.sjoin(df_ballparks, df_cities, how='right',op="within")
# Out:
# /Users/aaronwoodward/opt/anaconda3/lib/python3.7/site-packages/geopandas/tools/sjoin.py:61: UserWarning: CRS of frames being joined does not match!({'init': 'epsg:4326'} != {'init': 'epsg:4269'})
#   "(%s != %s)" % (left_df.crs, right_df.crs)

# %%
join_df.head(32)
# Out:
#              index_left                              NAME1              CITY  \
# index_right
# 702                 0.0           Angel Stadium of Anaheim           Anaheim
# 702                 5.0                     Dodger Stadium       Los Angeles
# 119                 1.0                        Chase Field           Phoenix
# 1633                2.0                 Citizens Bank Park      Philadelphia
# 846                 3.0                      Comerica Park           Detroit
# 3525                4.0                        Coors Field            Denver
# 3302                6.0                        Fenway Park            Boston
# 1433                7.0           Great American Ball Park        Cincinnati
# 59                  8.0                  Progressive Field         Cleveland
# 2628                9.0                   Kauffman Stadium       Kansas City
# 1035               10.0                        Miller Park         Milwaukee
# 386                11.0                    MinuteMaid Park           Houston
# 1447               12.0                      Busch Stadium       Saint Louis
# 368                13.0        Oriole Park at Camden Yards         Baltimore
# 793                14.0                          AT&T Park     San Francisco
# 793                28.0    Oakland-Alameda County Coliseum           Oakland
# 601                15.0                         PETCO Park         San Diego
# 3295               16.0                           PNC Park        Pittsburgh
# 3493               17.0                       Safeco Field           Seattle
# 2627               18.0                         Citi Field          Flushing
# 2627               24.0                 New Yankee Stadium          New York
# 275                19.0      Rangers Ballpark in Arlington         Arlington
# 531                20.0                    Tropicana Field  Saint Petersburg
# 2443               21.0                       Turner Field           Atlanta
# 789                22.0  US Cellular Field (Comiskey Park)           Chicago
# 789                23.0                      Wrigley Field           Chicago
# 143                25.0                     Nationals Park        Washington
# 426                26.0                       Target Field       Minneapolis
# 346                27.0                   Sun Life Stadium             Miami
# 0                   NaN                                NaN               NaN
# 1                   NaN                                NaN               NaN
# 2                   NaN                                NaN               NaN
#
#             STATE                           TEAM UACE10      AFFGEOID10  \
# index_right
# 702            CA  Los Angeles Angels of Anaheim  51445  400C100US51445
# 702            CA            Los Angeles Dodgers  51445  400C100US51445
# 119            AZ           Arizona Diamondbacks  69184  400C100US69184
# 1633           PA          Philadelphia Phillies  69076  400C100US69076
# 846            MI                 Detroit Tigers  23824  400C100US23824
# 3525           CO               Colorado Rockies  23527  400C100US23527
# 3302           MA                 Boston Red Sox  09271  400C100US09271
# 1433           OH                Cincinnati Reds  16885  400C100US16885
# 59             OH              Cleveland Indians  17668  400C100US17668
# 2628           MO             Kansas City Royals  43912  400C100US43912
# 1035           WI              Milwaukee Brewers  57466  400C100US57466
# 386            TX                 Houston Astros  40429  400C100US40429
# 1447           MO          Saint Louis Cardinals  77770  400C100US77770
# 368            MD              Baltimore Orioles  04843  400C100US04843
# 793            CA           San Francisco Giants  78904  400C100US78904
# 793            CA              Oakland Athletics  78904  400C100US78904
# 601            CA               San Diego Padres  78661  400C100US78661
# 3295           PA             Pittsburgh Pirates  69697  400C100US69697
# 3493           WA               Seattle Mariners  80389  400C100US80389
# 2627           NY                  New York Mets  63217  400C100US63217
# 2627           NY               New York Yankees  63217  400C100US63217
# 275            TX                  Texas Rangers  22042  400C100US22042
# 531            FL                 Tampa Bay Rays  86599  400C100US86599
# 2443           GA                 Atlanta Braves  03817  400C100US03817
# 789            IL              Chicago White Sox  16264  400C100US16264
# 789            IL                   Chicago Cubs  16264  400C100US16264
# 143            DC           Washington Nationals  92242  400C100US92242
# 426            MN                Minnesota Twins  57628  400C100US57628
# 346            FL                Florida Marlins  56602  400C100US56602
# 0             NaN                            NaN  88732  400C100US88732
# 1             NaN                            NaN  01819  400C100US01819
# 2             NaN                            NaN  22366  400C100US22366
#
#             GEOID10                                NAME10 LSAD10 UATYP10  \
# index_right
# 702           51445  Los Angeles--Long Beach--Anaheim, CA     75       U
# 702           51445  Los Angeles--Long Beach--Anaheim, CA     75       U
# 119           69184                     Phoenix--Mesa, AZ     75       U
# 1633          69076          Philadelphia, PA--NJ--DE--MD     75       U
# 846           23824                           Detroit, MI     75       U
# 3525          23527                    Denver--Aurora, CO     75       U
# 3302          09271                    Boston, MA--NH--RI     75       U
# 1433          16885                Cincinnati, OH--KY--IN     75       U
# 59            17668                         Cleveland, OH     75       U
# 2628          43912                   Kansas City, MO--KS     75       U
# 1035          57466                         Milwaukee, WI     75       U
# 386           40429                           Houston, TX     75       U
# 1447          77770                     St. Louis, MO--IL     75       U
# 368           04843                         Baltimore, MD     75       U
# 793           78904            San Francisco--Oakland, CA     75       U
# 793           78904            San Francisco--Oakland, CA     75       U
# 601           78661                         San Diego, CA     75       U
# 3295          69697                        Pittsburgh, PA     75       U
# 3493          80389                           Seattle, WA     75       U
# 2627          63217          New York--Newark, NY--NJ--CT     75       U
# 2627          63217          New York--Newark, NY--NJ--CT     75       U
# 275           22042     Dallas--Fort Worth--Arlington, TX     75       U
# 531           86599             Tampa--St. Petersburg, FL     75       U
# 2443          03817                           Atlanta, GA     75       U
# 789           16264                       Chicago, IL--IN     75       U
# 789           16264                       Chicago, IL--IN     75       U
# 143           92242                Washington, DC--VA--MD     75       U
# 426           57628         Minneapolis--St. Paul, MN--WI     75       U
# 346           56602                             Miami, FL     75       U
# 0             88732                            Tucson, AZ     75       U
# 1             01819                           Alturas, CA     76       C
# 2             22366                     Davenport, IA--IL     75       U
#
#                 ALAND10   AWATER10  \
# index_right
# 702          4500807839   57052601
# 702          4500807839   57052601
# 119          2968685079   12697349
# 1633         5132240328  127543480
# 846          3460893786   94001027
# 3525         1726058510   38089345
# 3302         4853336622  201355196
# 1433         2040396726   24339712
# 59           2004098980   11901959
# 2628         1755750548   18068132
# 1035         1413151381   49351861
# 386          4302687622   85070268
# 1447         2391104325   30364063
# 368          1856864888   65405866
# 793          1356417269   24620473
# 793          1356417269   24620473
# 601          1899682371   71754528
# 3295         2344771177   42038622
# 3493         2614905764  174194014
# 2627         8934084608  534984232
# 2627         8934084608  534984232
# 275          4610136194   92202220
# 531          2478304156  211073079
# 2443         6851581056   93257528
# 789          6321883815  110183753
# 789          6321883815  110183753
# 143          3424394645   69354873
# 426          2644805711  233882416
# 346          3182870193  217364584
# 0             915276150    2078695
# 1               4933312      16517
# 2             357345121   21444164
#
#                                                       geometry
# index_right
# 702          MULTIPOLYGON (((-117.50582 34.15048, -117.5014...
# 702          MULTIPOLYGON (((-117.50582 34.15048, -117.5014...
# 119          MULTIPOLYGON (((-111.43253 33.37751, -111.4321...
# 1633         MULTIPOLYGON (((-74.68335 39.98373, -74.67821 ...
# 846          MULTIPOLYGON (((-82.76862 42.72953, -82.76760 ...
# 3525         MULTIPOLYGON (((-104.71571 39.52160, -104.7154...
# 3302         MULTIPOLYGON (((-70.75589 42.08023, -70.75351 ...
# 1433         MULTIPOLYGON (((-84.05054 39.05261, -84.05048 ...
# 59           MULTIPOLYGON (((-81.09328 41.76613, -81.09313 ...
# 2628         MULTIPOLYGON (((-94.15155 39.01438, -94.14788 ...
# 1035         MULTIPOLYGON (((-87.92842 43.30931, -87.92522 ...
# 386          MULTIPOLYGON (((-94.84651 29.81921, -94.84624 ...
# 1447         MULTIPOLYGON (((-89.85317 38.59027, -89.84981 ...
# 368          MULTIPOLYGON (((-76.34700 38.96715, -76.34092 ...
# 793          MULTIPOLYGON (((-122.19717 38.04922, -122.1971...
# 793          MULTIPOLYGON (((-122.19717 38.04922, -122.1971...
# 601          MULTIPOLYGON (((-116.71106 32.84909, -116.7068...
# 3295         MULTIPOLYGON (((-79.26040 40.37182, -79.24772 ...
# 3493         MULTIPOLYGON (((-121.92866 47.63873, -121.9268...
# 2627         MULTIPOLYGON (((-72.35716 40.90963, -72.35495 ...
# 2627         MULTIPOLYGON (((-72.35716 40.90963, -72.35495 ...
# 275          MULTIPOLYGON (((-96.32675 32.97119, -96.32232 ...
# 531          MULTIPOLYGON (((-82.06386 27.97467, -82.05971 ...
# 2443         MULTIPOLYGON (((-83.71458 34.10093, -83.71320 ...
# 789          MULTIPOLYGON (((-87.00951 41.64198, -87.00311 ...
# 789          MULTIPOLYGON (((-87.00951 41.64198, -87.00311 ...
# 143          MULTIPOLYGON (((-76.71207 38.81400, -76.71064 ...
# 426          MULTIPOLYGON (((-92.80051 45.05737, -92.79728 ...
# 346          MULTIPOLYGON (((-80.16238 25.73163, -80.16081 ...
# 0            MULTIPOLYGON (((-110.81345 32.11910, -110.7987...
# 1            MULTIPOLYGON (((-120.54610 41.51264, -120.5459...
# 2            MULTIPOLYGON (((-90.36678 41.53636, -90.36462 ...

# %% [markdown]
# We've successfully spatial joined the two GeoDataFrames. The joined GeoDataFrame, join_df, lists the items that were joined first. Notice, that there are two new columns as result of the sjoin: index_right and index_left. Index_right are the index references of the df_cities, and index_left are the index references of df_ballparks. After the joined items, there are a list of cities that do not have an MLB ballpark, therefore an sjoin was not possible to be performed. We can tidy join_df by removing these excess rows by simply selecting one of the MLB ballpark columns ("NAME1", "CITY", "STATE", "TEAM") and making it not equal (!=) to "NaN" (Not a number).

# %%
join_df != join_df[join_df["NAME1"]!="NaN"]

# %% [markdown]
# Or, you can simply use the pandas ".dropna()" function to also achieve this.

# %%
join_df = join_df.dropna()

# %% [markdown]
# Now, we have a cleaned joined GeoDataframe! There was one MLB ballpark that we were not able to join because the MLB team that plays its home games in a MLB ballpark outside the U.S. Can you identify the MLB team?

# %% [markdown]
# ## Bonus: Converting geospatial coordinates into a geography

# %% [markdown]
# ### Make a dataset of some famous landmarks and obtaining their geospatial coordinates

# %%
landmarks_df = pd.read_csv('Landmarks.csv')
landmarks_df.head()
# Out:
#                 Landmark           City Country    Lat     Lon
# 0  Empire State Building  New York City     USA  40.75  -73.99
# 1     Golden Gate Bridge  San Francisco     USA  37.82 -122.47
# 2    Washington Monument  Washington DC     USA  38.89  -77.03
# 3    House of Parliament         London      UK  51.50   -0.12
# 4           Eiffel Tower         Paris   France  48.86    2.29

# %% [markdown]
# We'll convert the DataFrame into a GeoDataFrame by transforming the longitude and latitude into a geometry.

# %%
landmarks_gdf = gpd.GeoDataFrame(landmarks_df, geometry=gpd.points_from_xy(landmarks_df.Lat, landmarks_df.Lon))
landmarks_gdf
# Out:
#                 Landmark           City    Country    Lat     Lon  \
# 0  Empire State Building  New York City        USA  40.75  -73.99
# 1     Golden Gate Bridge  San Francisco        USA  37.82 -122.47
# 2    Washington Monument  Washington DC        USA  38.89  -77.03
# 3    House of Parliament         London         UK  51.50   -0.12
# 4           Eiffel Tower         Paris      France  48.86    2.29
# 5              Colosseum           Rome      Italy  41.90   12.49
# 6     Sydney Opera House        Sydney   Australia -33.86  151.22
# 7            Tokyo Tower          Tokyo      Japan  35.66  139.75
#
#                   geometry
# 0   POINT (40.750 -73.990)
# 1  POINT (37.820 -122.470)
# 2   POINT (38.890 -77.030)
# 3    POINT (51.500 -0.120)
# 4     POINT (48.860 2.290)
# 5    POINT (41.900 12.490)
# 6  POINT (-33.860 151.220)
# 7   POINT (35.660 139.750)

# %% [markdown]
# One important note to make. When working with shapefiles, the longitude coordinates are listed first in the geometry. In this example, latitude is listed first, which should be avoided because when plotting coordinates the first coordinate reference will be recognized as longitude. Therefore it's advised that longitude should be listed first, then latitude.

# %%
                                ### END OF CODE ###
